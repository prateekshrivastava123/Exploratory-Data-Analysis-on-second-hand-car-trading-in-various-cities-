# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
title=[]
price=[]
l=[1, 2, 4,5,7,8,9,10,16,70,43,23,33]
for i in l:
    url='https://www.cartrade.com/buy-used-cars/hyderabad/c/#so=-1&sc=-1&city=105&car='+str(i)
    page=requests.get(url)
    soup=BeautifulSoup(page.text, "html.parser")
    a =soup.find_all('h2', class_="h2heading truncate") 
    for i in a:
        title.append(i.text.strip())
    p=soup.find_all('div', class_='cr_prc')
    for i in p:
        price.append(i.text)
    c =soup.find_all('div', class_="info_cr_new")
    for i in c:
        print(i.text)
# Out:
# 51,000 KMs|Petrol|Hyderabad
#
# 77,700 KMs|Petrol|Hyderabad
#
# 80,070 KMs|Electric|Hyderabad
#
# 56,000 KMs|Petrol|Hyderabad
#
# 1,20,000 KMs|Diesel|Hyderabad
#
# 89,989 KMs|Diesel|Hyderabad
#
# 70,002 KMs|Petrol|Hyderabad
#
# 68,325 KMs|Diesel|Hyderabad
#
# 71,123 KMs|Diesel|Hyderabad
#
# 64,260 KMs|Diesel|Hyderabad
#
# 52,060 KMs|Petrol|Hyderabad
#
# 74,340 KMs|Petrol|Hyderabad
#
# 16,783 KMs|Petrol|Hyderabad
#
# 86,252 KMs|Petrol|Hyderabad
#
# 75,304 KMs|Petrol|Hyderabad
#
# 11,510 KMs|Petrol|Hyderabad
#
# 22,251 KMs|Petrol|Hyderabad
#
# 7,381 KMs|Petrol|Hyderabad
#
# 1,04,407 KMs|Petrol|Hyderabad
#
# 62,423 KMs|Petrol|Hyderabad
#
# 95,753 KMs|Petrol|Hyderabad
#
# 21,794 KMs|Petrol|Hyderabad
#
# 97,610 KMs|Petrol|Hyderabad
#
# 42,162 KMs|Petrol|Hyderabad
#
# 1,03,572 KMs|Petrol|Hyderabad
#
# 85,855 KMs|Diesel|Hyderabad
#
# 14,859 KMs|Petrol|Hyderabad
#
# 12,531 KMs|Petrol|Hyderabad
#
# 84,658 KMs|Petrol|Hyderabad
#
# 40,968 KMs|Petrol|Hyderabad
#
# 93,133 KMs|Petrol|Hyderabad
#
# ...

# %%
len(title)
# Out:
# 416

# %%
len(price)
# Out:
# 416

# %%
import re

# %%
price_final=[]
for i in price:
    p='^₹(\d+.*)'
    price_u=re.findall(p,i)
    price_final.append(price_u)

# %%
d={'title': title, 'price_in_rupees':price_final}

# %%
import pandas as pd

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#                                            title price_in_rupees
# 0          2020 Volkswagen Vento Highline Petrol      [9,65,000]
# 1         2022 MG Astor Sharp 1.5 MT [2021-2023]     [15,50,000]
# 2      2018 Tata Nexon XZA Plus Diesel Dual Tone      [8,90,000]
# 3      2019 Maruti Suzuki Eeco 5 STR [2019-2020]      [5,70,000]
# 4                         2016 Honda City VX CVT      [8,25,000]
# ..                                           ...             ...
# 411        2020 Maruti Suzuki Ignis Zeta 1.2 AMT      [7,19,000]
# 412                 2018 Tata Tiago Revotron XZA      [5,56,000]
# 413           2012 Maruti Suzuki Alto LXi BS-III      [2,21,000]
# 414  2017 Maruti Suzuki Alto K10 VXi [2014-2019]      [3,29,000]
# 415           2012 Maruti Suzuki Swift DZire VDI      [4,36,000]
#
# [416 rows x 2 columns]

# %%
import requests

# %%
url='https://www.cartrade.com/buy-used-cars/hyderabad/c/#so=-1&sc=-1&city=105'

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
soup=BeautifulSoup(page.text, "html.parser")

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en" xmlns="http://www.w3.org/1999/xhtml"><head prefix="og: https://ogp.me/ns# fb: https://ogp.me/ns/fb#"><script>(function (w, d, s, l, i) {
# 			w[l] = w[l] || []; w[l].push({
# 				'gtm.start':
# 					new Date().getTime(), event: 'gtm.js'
# 			}); var f = d.getElementsByTagName(s)[0],
# 				j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# 					'//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# ...

# %%
a =soup.find_all('h2', class_="h2heading truncate")

# %%
brand = []
for i in a:
    text = i.text
    regex=re.findall("\s\\W+\s(\d+)",text)
    
    brand.append(regex)

# %%
len(brand)
# Out:
# 32

# %%
len(brand)
# Out:
# 24

# %%
brand[0]
# Out:
# '\n\t\t\t\t\t\t\t\t\t\t\t\t2023 Citroen C3 Feel 1.2 Petrol Vibe Pack Dual Tone [2022]\n\t\t\t\t\t\t\t\t\t\t\t'

# %%
brand
# Out:
# ['\n\t\t\t\t\t\t\t\t\t\t\t\t2023 Citroen C3 Feel 1.2 Petrol Vibe Pack Dual Tone [2022]\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t2022 Toyota Hilux High 4X4 MT\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t2022 Honda Amaze 1.2 VX CVT Petrol [2019-2020]\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t2022 Volvo XC60 B5 Inscription\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t2022 MG Astor Savvy 1.3 Turbo AT S Red [2021-2023]\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t2022 Mahindra XUV300 1.5 W6 [2019-2020]\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t2022 Toyota Innova Crysta GX 2.4 8 STR\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t2022 Toyota Innova Crysta GX 2.4 7 STR\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t2022 Honda Amaze 1.2 VX CVT Petrol [2019-2020]\n\t\t\t\t\t\t\t\t\t\t\t',
# ...

# %%
import re

# %%
brands = []
for i in brand:
    i = i.replace('\t','')
    i = i.replace('\n','')
    i = i.split()
    i = i[1:3]
    brands.append(i)

# %%
brands
# Out:
# [['Citroen', 'C3'],
#  ['Toyota', 'Hilux'],
#  ['Honda', 'Amaze'],
#  ['Volvo', 'XC60'],
#  ['MG', 'Astor'],
#  ['Mahindra', 'XUV300'],
#  ['Toyota', 'Innova'],
#  ['Toyota', 'Innova'],
#  ['Honda', 'Amaze'],
#  ['Mahindra', 'XUV700'],
#  ['Audi', 'A4'],
#  ['Nissan', 'Magnite'],
#  ['Mahindra', 'XUV700'],
#  ['Maruti', 'Suzuki'],
#  ['Volkswagen', 'Virtus'],
#  ['Honda', 'Jazz'],
#  ['Toyota', 'Urban'],
#  ['Toyota', 'Fortuner'],
#  ['Maruti', 'Suzuki'],
#  ['Kia', 'Carnival'],
#  ['Tata', 'Safari'],
#  ['Skoda', 'Kushaq'],
#  ['Hyundai', 'Creta'],
#  ['Tata', 'Harrier']]

# %%
len(brands)
# Out:
# 24

# %%
for i in a:
    brand.append(i.text)

# %%
model=[]
for i in a:
    text=i.text
    text= text.replace(',', '')
    regex=re.findall("\t(\d+)\s\w+",text)
    model.append(regex)

# %%
model
# Out:
# [['2023'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022'],
#  ['2022']]

# %%
flattened_list = [item for sublist in model for item in sublist]
model_year = ', '.join(flattened_list)
model_year = model_year.split(',')

# %%
model_year
# Out:
# ['2023',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022',
#  ' 2022']

# %%
len(model_year)
# Out:
# 24

# %%
b =soup.find_all('div', class_="cr_prc")

# %%
b
# Out:
# [<div class="cr_prc"><span class="rupee_font font_20">₹</span>9,00,000
#  														<span class="negotiate splLinks make-offer-divider" cwt="" data-action="NegotiateShown" data-cat="UsedCarSearch" data-event="CWNonInteractive" data-label="profileId=D3864543|originId=63|rank=|platformid=302" data-role="impression" onclick="buyerFormV2Desktop.getMakeOffer('D3864543', 'Citroen C3 Feel 1.2 Petrol Vibe Pack Dual Tone [2022]','9,00,000', '900000',
#  														'', '0', '63',0)">Make
#  													Offer</span></div>,
#  <div class="cr_prc"><span class="rupee_font font_20">₹</span>38,38,000
#  														<span class="negotiate splLinks make-offer-divider" cwt="" data-action="NegotiateShown" data-cat="UsedCarSearch" data-event="CWNonInteractive" data-label="profileId=D3883851|originId=63|rank=|platformid=302" data-role="impression" onclick="buyerFormV2Desktop.getMakeOffer('D3883851', 'Toyota Hilux High 4X4 MT','38,38,000', '3838000',
#  														'', '0', '63',0)">Make
# ...

# %%
b[0].text
# Out:
# '₹9,00,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer'

# %%
price_=[]
for i in b:
    
    price_.append(i.text)

# %%
price_
# Out:
# ['₹9,00,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹38,38,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹9,85,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹67,00,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹20,00,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹11,25,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹24,50,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹24,00,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹9,60,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹26,70,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
#  '₹47,00,000\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer',
# ...

# %%
price = []
for i in range(len(price_)):
    price.append(price_[i].replace("\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMake\n\t\t\t\t\t\t\t\t\t\t\t\t\tOffer" , "").strip())
price
# Out:
# ['₹9,00,000',
#  '₹38,38,000',
#  '₹9,85,000',
#  '₹67,00,000',
#  '₹20,00,000',
#  '₹11,25,000',
#  '₹24,50,000',
#  '₹24,00,000',
#  '₹9,60,000',
#  '₹26,70,000',
#  '₹47,00,000',
#  '₹10,65,000',
#  '₹15,50,000',
#  '₹6,55,000',
#  '₹18,50,000',
#  '₹9,67,000',
#  '₹11,95,000',
#  '₹45,00,000',
#  '₹6,99,900',
#  '₹38,00,000',
#  '₹24,25,000',
#  '₹17,70,000',
#  '₹17,75,000',
#  '₹21,60,000']

# %%
len(price)
# Out:
# 24

# %%
c =soup.find_all('div', class_="info_cr_new")

# %%
c
# Out:
# [<div class="info_cr_new"><ul><li>13,000 KMs</li><li>|</li><li>Diesel</li><li>|</li><li>Hyderabad</li></ul><br/><ul class="clear"><li>
#  </li></ul></div>,
#  <div class="info_cr_new"><ul><li>76,000 KMs</li><li>|</li><li>Diesel</li><li>|</li><li>Hyderabad</li></ul><br/><ul class="clear"><li>
#  </li></ul></div>,
#  <div class="info_cr_new"><ul><li>77,700 KMs</li><li>|</li><li>Petrol</li><li>|</li><li>Hyderabad</li></ul><br/><ul class="clear"><li>
#  </li></ul></div>,
#  <div class="info_cr_new"><ul><li>1,07,000 KMs</li><li>|</li><li>Diesel</li><li>|</li><li>Hyderabad</li></ul><br/><ul class="clear"><li>
#  </li></ul></div>,
#  <div class="info_cr_new"><ul><li>85,000 KMs</li><li>|</li><li>Diesel</li><li>|</li><li>Hyderabad</li></ul><br/><ul class="clear"><li>
#  </li></ul></div>,
#  <div class="info_cr_new"><ul><li>19,463 KMs</li><li>|</li><li>Petrol</li><li>|</li><li>Hyderabad</li></ul><br/><ul class="clear"><li>
#  </li></ul></div>,
# ...

# %%
for i in c:
    print(i.text)
# Out:
# 13,000 KMs|Diesel|Hyderabad
#
# 76,000 KMs|Diesel|Hyderabad
#
# 77,700 KMs|Petrol|Hyderabad
#
# 1,07,000 KMs|Diesel|Hyderabad
#
# 85,000 KMs|Diesel|Hyderabad
#
# 19,463 KMs|Petrol|Hyderabad
#
# 1,00,000 KMs|Diesel|Hyderabad
#
# 62,000 KMs|Petrol|Hyderabad
#
# 71,123 KMs|Diesel|Hyderabad
#
# 64,260 KMs|Diesel|Hyderabad
#
# 74,340 KMs|Petrol|Hyderabad
#
# 52,060 KMs|Petrol|Hyderabad
#
# 16,696 KMs|Petrol|Hyderabad
#
# 75,304 KMs|Petrol|Hyderabad
#
# 86,252 KMs|Petrol|Hyderabad
#
# 11,347 KMs|Petrol|Hyderabad
#
# 22,167 KMs|Petrol|Hyderabad
#
# 7,381 KMs|Petrol|Hyderabad
#
# 1,04,407 KMs|Petrol|Hyderabad
#
# 62,423 KMs|Petrol|Hyderabad
#
# 21,794 KMs|Petrol|Hyderabad
#
# 95,753 KMs|Petrol|Hyderabad
#
# 1,03,572 KMs|Petrol|Hyderabad
#
# 97,610 KMs|Petrol|Hyderabad
#
# 42,162 KMs|Petrol|Hyderabad
#
# 85,855 KMs|Diesel|Hyderabad
#
# 12,531 KMs|Petrol|Hyderabad
#
# 14,859 KMs|Petrol|Hyderabad
#
# 84,658 KMs|Petrol|Hyderabad
#
# 40,877 KMs|Petrol|Hyderabad
#
# 93,133 KMs|Petrol|Hyderabad
#
# ...

# %%
km=[]
for i in c:
    h

# %%
km
# Out:
# [['13000'],
#  ['76000'],
#  ['77700'],
#  ['107000'],
#  ['85000'],
#  ['19463'],
#  ['100000'],
#  ['62000'],
#  ['71123'],
#  ['64260'],
#  ['74340'],
#  ['52060'],
#  ['16696'],
#  ['75304'],
#  ['86252'],
#  ['11347'],
#  ['22167'],
#  ['7381'],
#  ['104407'],
#  ['62423'],
#  ['21794'],
#  ['95753'],
#  ['103572'],
#  ['97610'],
#  ['42162'],
#  ['85855'],
#  ['12531'],
#  ['14859'],
#  ['84658'],
#  ['40877'],
#  ['93133'],
#  ['99165']]

# %%
flattened_list = [item for sublist in km for item in sublist]
KMs= ', '.join(flattened_list)
KMs = KMs.split(',')

# %%
KMs
# Out:
# ['13000',
#  ' 76000',
#  ' 77700',
#  ' 107000',
#  ' 85000',
#  ' 19463',
#  ' 100000',
#  ' 62000',
#  ' 71123',
#  ' 64260',
#  ' 74340',
#  ' 52060',
#  ' 16696',
#  ' 75304',
#  ' 86252',
#  ' 11347',
#  ' 22167',
#  ' 7381',
#  ' 104407',
#  ' 62423',
#  ' 21794',
#  ' 95753',
#  ' 103572',
#  ' 97610',
#  ' 42162',
#  ' 85855',
#  ' 12531',
#  ' 14859',
#  ' 84658',
#  ' 40877',
#  ' 93133',
#  ' 99165']

# %%
len(KMs)
# Out:
# 32

# %%
Type=[]
for i in c:
    text=i.text
    text= text.replace(',', '')
    
    regex=re.findall("\|\w+\|",text)
    Type.append(regex)

# %%
Type
# Out:
# [['|Petrol|'],
#  ['|Diesel|'],
#  ['|Petrol|'],
#  ['|Hybrid|'],
#  ['|Petrol|'],
#  ['|Diesel|'],
#  ['|Diesel|'],
#  ['|Diesel|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Diesel|'],
#  ['|Petrol|'],
#  ['|Diesel|'],
#  ['|Diesel|'],
#  ['|Petrol|'],
#  ['|Petrol|'],
#  ['|Diesel|']]

# %%
len(Type)
# Out:
# 24

# %%
location=[]
for i in c:
    text=i.text
    text= text.replace(',', '')
    regex=re.findall("\|\w+\s",text)
    print(regex)
    
    location.append(regex)
# Out:
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Delhi\n']
# ['|Bangalore\n']
# ['|Hyderabad\n']
# ['|Delhi\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Hyderabad\n']
# ['|Delhi\n']
# ['|Delhi\n']
# ['|Delhi\n']
# ['|Delhi\n']

# %%
location
# Out:
# [['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Delhi\n'],
#  ['|Bangalore\n'],
#  ['|Hyderabad\n'],
#  ['|Delhi\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Hyderabad\n'],
#  ['|Delhi\n'],
#  ['|Delhi\n'],
#  ['|Delhi\n'],
#  ['|Delhi\n']]

# %%
d =soup.find_all('div', class_="splLinks-wrap")

# %%
d
# Out:
# [<div class="splLinks-wrap">
#  <span class="pull-left font_13 color-grey">EMI starts at <a class="color-bright-red bold_text splLinks font_13" data-action="Instant_Loan_Click" data-cat="UsedCarSearch" data-event="CWInteractive" data-label="D3864543" data-role="click-tracking" href="https://www.cartrade.com/used-car-finance/7242828/step1" target="_blank">₹14,946</a></span>
# ...

# %%
for i in d:
    print(i.text)
# Out:
# EMI starts at ₹14,946
# Newly Launched
#
#
#
# EMI starts at ₹63,736
#
#
# EMI starts at ₹16,357
#
#
# EMI starts at ₹1.11 L
# Home Test Drive
#
#
#
# Home Test Drive
#
#
#
# EMI starts at ₹18,682
# Home Test Drive
#
#
#
# EMI starts at ₹40,686
# Home Test Drive
#
#
#
# EMI starts at ₹39,856
# Home Test Drive
#
#
#
# EMI starts at ₹15,942
# Home Test Drive
#
#
#
# EMI starts at ₹44,339
# Home Test Drive
#
#
#
# EMI starts at ₹78,051
# Home Test Drive
#
#
#
# EMI starts at ₹17,686
# Home Test Drive
#
#
#
# EMI starts at ₹25,740
# Home Test Drive
#
#
#
# EMI starts at ₹10,877
# Home Test Drive
#
#
#
# EMI starts at ₹30,722
# Home Test Drive
#
#
#
# EMI starts at ₹16,058
# Quality Report
#
#
#
# EMI starts at ₹19,844
# Home Test Drive
#
#
#
# EMI starts at ₹74,730
#
#
# EMI starts at ₹11,623
# Home Test Drive
#
#
#
# EMI starts at ₹63,105
# Home Test Drive
#
#
#
# EMI starts at ₹40,271
# Home Test Drive
#
#
#
# EMI starts at ₹29,393
# Home Test Drive
#
#
#
# EMI starts at ₹29,476
# ...

# %%
EMI=[]
for i in d:
    text=i.text
    text= text.replace(',', '')
    
    
    regex=re.findall("\s\\W+(\d+)\s",text)
    EMI.append(regex)

# %%
EMI
# Out:
# [['14946'],
#  ['63736'],
#  ['16357'],
#  [],
#  [],
#  ['18682'],
#  ['40686'],
#  ['39856'],
#  ['15942'],
#  ['44339'],
#  ['78051'],
#  ['17686'],
#  ['25740'],
#  ['10877'],
#  ['30722'],
#  ['16058'],
#  ['19844'],
#  ['74730'],
#  ['11623'],
#  ['63105'],
#  ['40271'],
#  ['29393'],
#  ['29476'],
#  ['35870']]

# %%
flattened_list = [item for sublist in EMI for item in sublist]
EMIs= ', '.join(flattened_list)
EMIs = EMIs.split(',')

# %%
EMIs
# Out:
# ['14946',
#  ' 63736',
#  ' 16357',
#  ' 18682',
#  ' 40686',
#  ' 39856',
#  ' 15942',
#  ' 44339',
#  ' 78051',
#  ' 17686',
#  ' 25740',
#  ' 10877',
#  ' 30722',
#  ' 16058',
#  ' 19844',
#  ' 74730',
#  ' 11623',
#  ' 63105',
#  ' 40271',
#  ' 29393',
#  ' 29476',
#  ' 35870']

# %%
len(EMIs)
# Out:
# 22
